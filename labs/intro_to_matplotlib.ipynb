# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Combine datasets

# %%
combine_data = pd.read_csv("source_data/combine.csv")
combine_data.head()
# Out:
#      id  Year             Name Position  HeightFeet  HeightInches  Weight  \
# 0  8984  2013  Quanterus Smith       DE           6             5     250
# 1  9002  2013       Abry Jones       DT           6             3     313
# 2  9004  2013     Bennie Logan       DT           6             2     309
# 3  9012  2013      John Boyett       FS           5            10     204
# 4  9018  2013    Bacarri Rambo       FS           6             0     211
#
#     Arms   Hands  FortyYD    ...     Bench  Round           College     Pick  \
# 0  33.25  10.375        0    ...         0      5  Western Kentucky  13(146)
# 1  35.00   9.750        0    ...        30      0               NaN      NaN
# 2  34.00  10.250        0    ...        30      3               LSU    5(67)
# 3  30.50   8.500        0    ...        27      6            Oregon  24(192)
# 4  31.00   9.250        0    ...        17      6           Georgia  23(191)
#
#    PickRound  PickTotal  FirstName  LastName HeightInchesTotal Wonderlic
# 0         13        146  Quanterus     Smith                77         0
# 1          0          0       Abry     Jones                75         0
# 2          5         67     Bennie     Logan                74         0
# 3         24        192       John    Boyett                70         0
# 4         23        191    Bacarri     Rambo                72         0
#
# [5 rows x 26 columns]
